# %%
# !pip install scikit-learn

# 필수 라이브러리 불러오기
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# 1. 샘플 데이터 생성 (100개 샘플, 10개 특성)
np.random.seed(42)
X = np.random.rand(100, 10)  # 0~1 사이 랜덤값

# 2. 데이터 스케일링 (표준화)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 3. PCA 모델 생성 및 학습 (2차원으로 축소)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# 4. 결과 출력
print("🔹 Original data shape:", X_scaled.shape)
print("🔹 PCA transformed data shape:", X_pca.shape)
print("🔹 Explained variance ratio (각 주성분의 기여도):", pca.explained_variance_ratio_)
print("🔹 Sum of explained variance ratio (총 설명된 분산 비율):", np.sum(pca.explained_variance_ratio_))

# 5. 시각화
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c='blue', alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('PCA Result')
plt.grid(True)
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 36.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# ...
# 🔹 Original data shape: (100, 10)
# 🔹 PCA transformed data shape: (100, 2)
# 🔹 Explained variance ratio (각 주성분의 기여도): [0.15709067 0.13574811]
# 🔹 Sum of explained variance ratio (총 설명된 분산 비율): 0.2928387759346593
